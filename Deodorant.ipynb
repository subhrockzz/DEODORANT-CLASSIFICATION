# %%
import pandas as pd

# %%
data=pd.read_csv('Deodrant_classification.csv')

# %%
data
# Out:
#       Respondent.ID  Product.ID      Product  Instant.Liking  \
# 0              3800         121  Deodorant B               1
# 1              3801         121  Deodorant B               0
# 2              3802         121  Deodorant B               0
# 3              3803         121  Deodorant B               1
# 4              3804         121  Deodorant B               1
# 5              3805         121  Deodorant B               0
# 6              3806         121  Deodorant B               0
# 7              3807         121  Deodorant B               0
# 8              3808         121  Deodorant B               0
# 9              3809         121  Deodorant B               1
# 10             3810         121  Deodorant B               0
# 11             3811         121  Deodorant B               0
# 12             3812         121  Deodorant B               0
# 13             3813         121  Deodorant B               1
# ...

# %%
data.isnull().sum()
# Out:
# Respondent.ID                                                 0
# Product.ID                                                    0
# Product                                                       0
# Instant.Liking                                                0
# q1_1.personal.opinion.of.this.Deodorant                       0
# q2_all.words                                                  0
# q3_1.strength.of.the.Deodorant                                0
# q4_1.artificial.chemical                                      0
# q4_2.attractive                                               0
# q4_3.bold                                                     0
# q4_4.boring                                                   0
# q4_5.casual                                                   0
# q4_6.cheap                                                    0
# q4_7.clean                                                    0
# q4_8.easy.to.wear                                             0
# ...

# %%
data=data.drop(['Respondent.ID','s13.2','s11.marital.status','ValSegb','s7.involved.in.the.selection.of.the.cosmetic.products','q2_all.words','s13a.b.most.often','q4_24.well.rounded','q4_23.upscale','q4_20.overpowering','q4_22.sophisticated','q4_13.high.quality','q4_21.sharp','q4_17.natural','q4_19.ordinary','q4_18.old.fashioned','q4_16.memorable','q10.prefer.this.Deodorant.or.your.usual.Deodorant','q11.time.of.day.would.this.Deodorant.be.appropriate','Product.ID','s7.involved.in.the.selection.of.the.cosmetic.products','q8.2','s12.working.status','q8.5','q8.6','q8.7','q8.8','q8.9','q8.10','q8.11','q8.12','q8.13','q8.17','q8.18','q8.19','q8.20','s10.income','q12.which.occasions.would.this.Deodorant.be.appropriate','Q13_Liking.after.30.minutes','s9.education','q8.1','q4_1.artificial.chemical','q7'],axis=1)

# %%
data
# Out:
#           Product  Instant.Liking  q1_1.personal.opinion.of.this.Deodorant  \
# 0     Deodorant B               1                                        4
# 1     Deodorant B               0                                        5
# 2     Deodorant B               0                                        6
# 3     Deodorant B               1                                        4
# 4     Deodorant B               1                                        4
# 5     Deodorant B               0                                        5
# 6     Deodorant B               0                                        7
# 7     Deodorant B               0                                        5
# 8     Deodorant B               0                                        6
# 9     Deodorant B               1                                        4
# 10    Deodorant B               0                                        6
# ...

# %%
data.isnull().sum()
# Out:
# Product                                                  0
# Instant.Liking                                           0
# q1_1.personal.opinion.of.this.Deodorant                  0
# q3_1.strength.of.the.Deodorant                           0
# q4_2.attractive                                          0
# q4_3.bold                                                0
# q4_4.boring                                              0
# q4_5.casual                                              0
# q4_6.cheap                                               0
# q4_7.clean                                               0
# q4_8.easy.to.wear                                        0
# q4_9.elegant                                             0
# q4_10.feminine                                           0
# q4_11.for.someone.like.me                                0
# q4_12.heavy                                              0
# q4_14.long.lasting                                       0
# ...

# %%
x=data.iloc[:,2:]
y=data.iloc[:,1]

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1
# 5       0
# 6       0
# 7       0
# 8       0
# 9       1
# 10      0
# 11      0
# 12      0
# 13      1
# 14      1
# 15      0
# 16      0
# 17      1
# 18      0
# 19      0
# 20      0
# 21      0
# 22      1
# 23      0
# 24      0
# 25      1
# 26      0
# 27      0
# 28      0
# 29      0
#        ..
# 2470    0
# 2471    0
# 2472    0
# 2473    0
# 2474    0
# 2475    0
# 2476    1
# 2477    0
# 2478    0
# 2479    0
# 2480    0
# 2481    0
# 2482    0
# 2483    1
# 2484    0
# 2485    0
# 2486    0
# 2487    0
# 2488    0
# 2489    1
# 2490    0
# 2491    1
# 2492    1
# 2493    0
# 2494    1
# 2495    0
# 2496    0
# 2497    1
# 2498    0
# 2499    0
# Name: Instant.Liking, Length: 2500, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15,random_state=40)

# %%
x_train
# Out:
#       q1_1.personal.opinion.of.this.Deodorant  q3_1.strength.of.the.Deodorant  \
# 1134                                        7                               3
# 170                                         6                               4
# 742                                         7                               3
# 1025                                        6                               3
# 2170                                        5                               3
# 1887                                        5                               4
# 997                                         6                               3
# 286                                         6                               3
# 1659                                        5                               3
# 1976                                        7                               3
# 635                                         6                               3
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
Log_reg=LogisticRegression()

# %%
Log_reg.fit(x_train,y_train)
# Out:
# /root/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred=Log_reg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.984

# %%
value_of_score=list()
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15,random_state=i)
    Log_reg.fit(x_train,y_train)
    y_pred=Log_reg.predict(x_test)
    score=accuracy_score(y_test,y_pred)
    value_of_score.append(score)
# Out:
# /root/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /root/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /root/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /root/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
max(value_of_score)
# Out:
# 1.0

# %%
value_of_score.index(max(value_of_score))
# Out:
# 35

# %%
import matplotlib.pyplot as plt
plt.scatter(range(1,100),value_of_score,color='orange')
plt.plot(range(1,100),value_of_score)
plt.axhline(max(value_of_score),color='red')
plt.axvline(36,color='green')

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15,random_state=36)
Log_reg.fit(x_train,y_train)
y_pred=Log_reg.predict(x_test)
score=accuracy_score(y_test,y_pred)
# Out:
# /root/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
score
# Out:
# 1.0
